# %% [markdown]
# ## 1. Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 2. Membaca Dataset

# %%
df = pd.read_csv('data.csv')

# Menampilkan dataset
df
# Out:
#                                            title   type  \
# 0                              The Fifth Element  movie
# 1                              Kill Bill: Vol. 1  movie
# 2                                        Jarhead  movie
# 3                                     Unforgiven  movie
# 4          Eternal Sunshine of the Spotless Mind  movie
# ...                                          ...    ...
# 20191                                        NaN     tv
# 20192                                        NaN     tv
# 20193                                        NaN     tv
# 20194                                        NaN     tv
# 20195  Blippi's Ultimate Bounce House Challenges     tv
#
#                               genres  releaseYear      imdbId  \
# 0          Action, Adventure, Sci-Fi       1997.0   tt0119116
# 1            Action, Crime, Thriller       2003.0   tt0266697
# 2              Biography, Drama, War       2005.0   tt0418763
# 3                     Drama, Western       1992.0   tt0105695
# 4             Drama, Romance, Sci-Fi       2004.0   tt0338013
# ...                              ...          ...         ...
# 20191                            NaN       2024.0         NaN
# 20192                          Drama       2024.0         NaN
# 20193  Animation, Action & Adventure       2016.0         NaN
# 20194                            NaN          NaN         NaN
# 20195                            NaN       2024.0  tt33769880
#
#        imdbAverageRating  imdbNumVotes  \
# 0                    7.6      517825.0
# 1                    8.2     1223791.0
# 2                    7.0      211961.0
# 3                    8.2      444585.0
# 4                    8.3     1106969.0
# ...                  ...           ...
# 20191                NaN           NaN
# 20192                NaN           NaN
# 20193                NaN           NaN
# 20194                NaN           NaN
# 20195                NaN           NaN
#
#                                       availableCountries
# 0                                             AT, CH, DE
# 1      AE, AL, AO, AT, AU, AZ, BG, BH, BY, CA, CI, CM...
# 2      AD, AE, AG, AL, AO, AT, AZ, BA, BG, BH, BM, BR...
# 3      AU, BA, BG, CZ, HR, HU, MD, ME, MK, NZ, PL, RO...
# 4      AD, AE, AG, AL, AO, AR, AU, AZ, BA, BB, BE, BG...
# ...                                                  ...
# 20191  AL, AZ, BA, BG, BY, CY, EE, FR, GF, HU, IT, LT...
# 20192  AO, CI, CM, CV, GH, GQ, KE, MG, ML, MU, MZ, NE...
# 20193  FJ, HK, ID, IN, JP, KR, MU, MY, PH, PK, SG, TH...
# 20194  FJ, HK, ID, IN, JP, KR, MU, MY, PH, PK, SG, TH...
# 20195  AG, AL, AO, AU, AZ, BA, BB, BG, BM, BS, BY, BZ...
#
# [20196 rows x 8 columns]

# %%
# Mengambil 450 data secara random
df_sampled = df.sample(n=450, random_state=42)

# %%
df_sampled
# Out:
#                                          title   type  \
# 10815  Pinkfong & Baby Shark's Space Adventure  movie
# 6541                   Bill Hicks: Reflections  movie
# 12460                    Herrie in Huize Gerri  movie
# 15180          Gold: A Journey with Idris Elba  movie
# 4199                      The Ryan White Story  movie
# ...                                        ...    ...
# 14836                          Beautiful Rebel  movie
# 2267                        Diabolically Yours  movie
# 3472                            An Air So Pure  movie
# 17124                          The Degenerates     tv
# 606                                   Æon Flux  movie
#
#                                           genres  releaseYear      imdbId  \
# 10815  Animation, Family, Music, Science Fiction       2019.0         NaN
# 6541                          Documentary, Short       2015.0   tt4558532
# 12460                                     Comedy       2021.0  tt15121700
# 15180                                Documentary       2023.0  tt32813758
# 4199                            Biography, Drama       1989.0   tt0098237
# ...                                          ...          ...         ...
# 14836                    Biography, Drama, Music       2024.0  tt28690443
# 2267                      Crime, Drama, Thriller       1967.0   tt0061568
# 3472                               Comedy, Drama       1997.0   tt0119853
# 17124                                     Comedy       2018.0   tt9077196
# 606                    Action, Adventure, Sci-Fi       2005.0   tt0402022
#
#        imdbAverageRating  imdbNumVotes  \
# 10815                NaN           NaN
# 6541                 6.8         179.0
# 12460                4.9         184.0
# 15180                6.5          46.0
# 4199                 7.1        1010.0
# ...                  ...           ...
# 14836                6.3         882.0
# 2267                 6.0        1965.0
# 3472                 5.9         139.0
# 17124                6.2         758.0
# 606                  5.4      134076.0
#
#                                       availableCountries
# 10815  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...
# 6541                                              MD, RO
# 12460                                                 NL
# 15180                             BM, GB, GG, GI, IE, TC
# 4199                                                  US
# ...                                                  ...
# 14836  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...
# 2267   BG, CY, CZ, DK, EE, ES, FI, GR, HR, HU, IS, LT...
# 3472   BG, CY, CZ, DK, EE, ES, FI, GR, HR, HU, IS, IT...
# 17124  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...
# 606    AE, AZ, BH, BY, DZ, EG, GB, IE, IQ, JO, KW, LB...
#
# [450 rows x 8 columns]

# %% [markdown]
# ## 3. Pemilihan Fitur

# %%
df_clustering = df_sampled[['imdbAverageRating', 'imdbNumVotes']].copy()

# %%
# Pengecekan terhadap missing values
print("Jumlah Missing Values sebelum penanganan:")
print(df_clustering.isnull().sum())
# Out:
# Jumlah Missing Values sebelum penanganan:
# imdbAverageRating    42
# imdbNumVotes         42
# dtype: int64

# %%
# Menangani kolom yang missing values menggunakan mean
df_clustering['imdbAverageRating'] = df_clustering['imdbAverageRating'].fillna(df_clustering['imdbAverageRating'].mean())
df_clustering['imdbNumVotes'] = df_clustering['imdbNumVotes'].fillna(df_clustering['imdbNumVotes'].mean())

# Mengecek kembali
print("Missing values setelah penanganan:")
print(df_clustering.isnull().sum())
# Out:
# Missing values setelah penanganan:
# imdbAverageRating    0
# imdbNumVotes         0
# dtype: int64

# %% [markdown]
# ## 4. Praproses Data (Standardisasi)

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_clustering)

# %% [markdown]
# ## 5. K-Means Clustering

# %%
kmeans = KMeans(n_clusters=2, n_init=10, random_state=42)
df_sampled['Cluster'] = kmeans.fit_predict(df_scaled)

# %% [markdown]
# ## 6. Visualisai hasil clustering

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_sampled['imdbAverageRating'], df_sampled['imdbNumVotes'], 
            c=df_sampled['Cluster'], cmap='viridis', marker='x')
plt.xlabel('IMDB Average Rating')
plt.ylabel('IMDB Number of Votes')
plt.title('Hasil Clustering Movie berdasarkan Rating dan Jumlah Suara')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

# %%
# Menampilkan informasi jumlah anggota tiap cluster
cluster_counts = df_sampled['Cluster'].value_counts()
print("\nJumlah anggota tiap cluster:")
print(cluster_counts)
# Out:
# Jumlah anggota tiap cluster:
# Cluster
# 0    443
# 1      7
# Name: count, dtype: int64

# %%
cluster_1 = df_sampled[df_sampled['Cluster'] == 0]
cluster_1
# Out:
#                                          title   type  \
# 10815  Pinkfong & Baby Shark's Space Adventure  movie
# 6541                   Bill Hicks: Reflections  movie
# 12460                    Herrie in Huize Gerri  movie
# 15180          Gold: A Journey with Idris Elba  movie
# 4199                      The Ryan White Story  movie
# ...                                        ...    ...
# 14836                          Beautiful Rebel  movie
# 2267                        Diabolically Yours  movie
# 3472                            An Air So Pure  movie
# 17124                          The Degenerates     tv
# 606                                   Æon Flux  movie
#
#                                           genres  releaseYear      imdbId  \
# 10815  Animation, Family, Music, Science Fiction       2019.0         NaN
# 6541                          Documentary, Short       2015.0   tt4558532
# 12460                                     Comedy       2021.0  tt15121700
# 15180                                Documentary       2023.0  tt32813758
# 4199                            Biography, Drama       1989.0   tt0098237
# ...                                          ...          ...         ...
# 14836                    Biography, Drama, Music       2024.0  tt28690443
# 2267                      Crime, Drama, Thriller       1967.0   tt0061568
# 3472                               Comedy, Drama       1997.0   tt0119853
# 17124                                     Comedy       2018.0   tt9077196
# 606                    Action, Adventure, Sci-Fi       2005.0   tt0402022
#
#        imdbAverageRating  imdbNumVotes  \
# 10815                NaN           NaN
# 6541                 6.8         179.0
# 12460                4.9         184.0
# 15180                6.5          46.0
# 4199                 7.1        1010.0
# ...                  ...           ...
# 14836                6.3         882.0
# 2267                 6.0        1965.0
# 3472                 5.9         139.0
# 17124                6.2         758.0
# 606                  5.4      134076.0
#
#                                       availableCountries  Cluster
# 10815  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...        0
# 6541                                              MD, RO        0
# 12460                                                 NL        0
# 15180                             BM, GB, GG, GI, IE, TC        0
# 4199                                                  US        0
# ...                                                  ...      ...
# 14836  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...        0
# 2267   BG, CY, CZ, DK, EE, ES, FI, GR, HR, HU, IS, LT...        0
# 3472   BG, CY, CZ, DK, EE, ES, FI, GR, HR, HU, IS, IT...        0
# 17124  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...        0
# 606    AE, AZ, BH, BY, DZ, EG, GB, IE, IQ, JO, KW, LB...        0
#
# [443 rows x 9 columns]

# %%
print("\nData anggota Cluster 2:")
cluster_2 = df_sampled[df_sampled['Cluster'] == 1]
cluster_2
# Out:
# Data anggota Cluster 2:
#                   title   type                     genres  releaseYear  \
# 4178   Captain Phillips  movie   Action, Biography, Crime       2013.0
# 34               Snatch  movie              Comedy, Crime       2000.0
# 10863       Oppenheimer  movie  Biography, Drama, History       2023.0
# 2796      The Conjuring  movie  Horror, Mystery, Thriller       2013.0
# 474       The Machinist  movie            Drama, Thriller       2004.0
# 2008              Blade  movie     Action, Horror, Sci-Fi       1998.0
# 2929     The Accountant  movie       Action, Crime, Drama       2016.0
#
#            imdbId  imdbAverageRating  imdbNumVotes  \
# 4178    tt1535109                7.8      500873.0
# 34      tt0208092                8.2      928703.0
# 10863  tt15398776                8.3      817524.0
# 2796    tt1457767                7.5      572481.0
# 474     tt0361862                7.6      422960.0
# 2008    tt0120611                7.1      310698.0
# 2929    tt2140479                7.3      332020.0
#
#                                       availableCountries  Cluster
# 4178   AG, AR, AU, AZ, BB, BE, BM, BO, BR, BS, BY, BZ...        1
# 34     AT, BE, CH, CY, DE, EE, FJ, GB, GG, GI, GR, HK...        1
# 10863                                     AU, BE, KR, NZ        1
# 2796   AD, AU, BA, BG, CH, CZ, ES, FJ, HK, HR, HU, ID...        1
# 474                                                   ES        1
# 2008   BA, BG, CZ, HR, HU, JP, KR, MD, ME, MK, PL, RO...        1
# 2929   AD, AT, BE, CA, CH, DE, ES, FR, GB, GF, GG, IE...        1
